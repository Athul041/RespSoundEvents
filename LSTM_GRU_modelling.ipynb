# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "drive/MyDrive/HF_Lung_V1/train.zip" -d "./HF_Lung_V1/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_2.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L6_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_2.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-13-11-32-14-L8_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_10.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L1_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_13.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_3.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L4_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_9.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_14.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_9.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L6_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_12.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_14.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_5.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-02-49-L8_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L1_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L4_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L6_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_11.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_12.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_14.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_8.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-10-32-54-L8_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L1_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L4_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L6_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_14_label.txt
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_2.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-02-58-L8_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L1_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-06-23-11-33-16-L4_12.wav
# ...
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_14.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_14.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L4_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_14.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_14_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_10.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_11.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-10-50-18-L8_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L1_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_13.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L2_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_13.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_5.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L4_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_0.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_1.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_13.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_13_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_1_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_2.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_2_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_3.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_3_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_4.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_4_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_5.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_5_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L5_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_10.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_10_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_11.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_7.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_7_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_8_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_9.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L6_9_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_0.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_0_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_11.wav
#  extracting: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_11_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_12.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_12_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_6.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_6_label.txt
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_8.wav
#   inflating: ./HF_Lung_V1/train/trunc_2019-07-31-11-20-43-L8_8_label.txt

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T
import torch.nn as nn
import torch.optim as optim
import random
import os
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split, Dataset

dataset_folder = './HF_Lung_V1'
train_data_path = os.path.join(dataset_folder, 'train')
test_data_path = os.path.join(dataset_folder, 'test')

SAMPLE_RATE = 4000
ALL_LABELS = ['I', 'D', 'E', 'Rhonchi', 'Wheeze', 'Stridor']

# %%
from scipy import signal
import librosa

class LungDataSet(Dataset):
    def __init__(self, file_list, transformations, targets_transform):
        self.file_list = file_list
        self.target_transform = targets_transform
        self.target_sample_rate = SAMPLE_RATE
        self.transformations = transformations

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):
        audio_sample_path = self._get_audio_sample_path(index)
        labels = self.__get_audio_sample_labels(index)

        # Read Audio from path
        wav, sample_rate = librosa.load(audio_sample_path, sr=None, mono=False)
        cutoff_freq = 80

        # Apply high pass filter cutoff = 80Hz, filter order = 10
        b, a = signal.butter(N=10, Wn=cutoff_freq,
                             btype='high', fs=sample_rate)
        wav_filtered = signal.filtfilt(b, a, wav)

        # Convert the np array to torch tensor and transfer to device
        torch_signal = torch.tensor(wav_filtered.copy()).float().reshape(1, -1)

        # Resample the signal to 4kHz
        torch_signal = self._resample_if_necessary(torch_signal, sample_rate)
        
        input_tensors = []
        # Apply transformations
        for transform in self.transformations:
            input_tensors.append(transform(torch_signal))
        input_tensor = torch.cat(input_tensors, dim=1)
        if self.target_transform:
            labels = self.target_transform(labels, input_tensor.shape[-1], sample_rate)

        self._min_max_normalize_input(input_tensor)

        return input_tensor, labels

    def _get_audio_sample_path(self, index):
        path = os.path.join(self.file_list[index] + ".wav")
        return path

    def __get_audio_sample_labels(self, index):
        path = os.path.join(self.file_list[index] + "_label.txt")
        labels = pd.read_csv(path, sep=' ', header=None,
                             names=["class", "start", "end"])
        labels['start'] = pd.to_timedelta(labels['start']).dt.total_seconds()
        labels['end'] = pd.to_timedelta(labels['end']).dt.total_seconds()
        return labels

    def _resample_if_necessary(self, signal, sr):
        if sr != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(
                sr, self.target_sample_rate)
            signal = resampler(signal)

        return signal
    def _min_max_normalize_input(self, audio_tensor):
        new_min, new_max = 0, 1
        v_min, v_max = audio_tensor.min(), audio_tensor.max()
        new_tensor = (audio_tensor - v_min)/(v_max - v_min)*(new_max - new_min) + new_min
        return new_tensor

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    torch.set_num_threads(5)
    print(f'Random seed {seed} has been set.')

# %%
class Net_1(nn.Module):
    def __init__(self, input_dimensions, n_hidden, output_dimensions, n_layers=1, drop_prob=0, bidirectional=False, device="cpu"):
        super(Net_1, self).__init__()

        self.n_features = input_dimensions
        self.n_hidden_units = n_hidden
        self.n_layers = n_layers
        self.drop_prob = drop_prob
        self.bidirectional = bidirectional
        self.n_out = output_dimensions
        self.device = device
        self.directions = 2 if self.bidirectional else 1

        self.lstm = nn.LSTM(input_size=self.n_features,
                            hidden_size=self.n_hidden_units,
                            num_layers=self.n_layers,
                            dropout=self.drop_prob,
                            batch_first=True,
                            bidirectional=self.bidirectional)

        # self.dropout = nn.Dropout(self.drop_prob)

        self.dense = nn.Linear(
            in_features=self.directions*self.n_hidden_units, out_features=self.n_out)

        # self.activation = nn.Sigmoid()

        self.network = nn.Sequential(self.lstm,
                                     self.dense)
        self.to(device)

    def forward(self, x):
        h_0 = torch.zeros(self.directions*self.n_layers, x.shape[0], self.n_hidden_units).to(self.device)
        c_0 = torch.zeros(self.directions*self.n_layers, x.shape[0], self.n_hidden_units).to(self.device)
        output, (h_t, c_t) = self.lstm(x, (h_0, c_0))
        output = self.dense(output)
        # output = self.activation(output)

        return output

# %%
class GRUNet(nn.Module):
    def __init__(self, input_dimensions, n_hidden, output_dimensions, n_layers=1, drop_prob=0, bidirectional=False, device="cpu"):
        super(GRUNet, self).__init__()

        self.n_features = input_dimensions
        self.n_hidden_units = n_hidden
        self.n_layers = n_layers
        self.drop_prob = drop_prob
        self.bidirectional = bidirectional
        self.n_out = output_dimensions
        self.device = device
        self.directions = 2 if self.bidirectional else 1

        self.gru = nn.GRU(input_size=self.n_features,
                            hidden_size=self.n_hidden_units,
                            num_layers=self.n_layers,
                            batch_first=True,
                            dropout=self.drop_prob,
                            bidirectional=self.bidirectional)

        # self.dropout = nn.Dropout(self.drop_prob)

        self.dense = nn.Linear(
            in_features=self.directions*self.n_hidden_units, out_features=self.n_out)

        # self.activation = nn.Sigmoid()

        self.network = nn.Sequential(self.gru,
                                     self.dense)
        self.to(device)

    def forward(self, x):
        h_0 = torch.zeros(self.directions*self.n_layers, x.shape[0], self.n_hidden_units).to(self.device)
        # c_0 = torch.zeros(self.directions*self.n_layers, x.shape[0], self.n_hidden_units).to(self.device)
        output, h_t = self.gru(x, h_0)
        output = self.dense(output)
        # output = self.activation(output)

        return output

# %%
def train_model(num_epochs, model, optimizer, scheduler, loss_fn, train_loader, validation_loader, device):
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    training_losses = []
    training_accuracy = []
    validation_losses = []
    validation_accuracy = []
    output_threshold = 0.5
    best_validation_loss = np.Inf
    for e in range(num_epochs):
        train_batch_loss = []
        validation_batch_loss = []
        train_batch_accuracy = []
        validation_batch_accuracy = []
        # update weights using training data

        model.train(True)
        for train_batch_id, (data, labels) in enumerate(train_loader):
            optimizer.zero_grad()
            data = data.to(device)
            labels = labels.to(device)
            out = model(data)
            # out = out[-1,:,:].squeeze()
            loss = loss_fn(out, labels)
            loss.backward()
            optimizer.step()

            pred = out.detach().cpu().numpy() > output_threshold
            accuracy = np.sum(pred == labels.detach().cpu().numpy(
                ))/(labels.shape[0]*labels.shape[1]*labels.shape[2])
            train_batch_loss.append(loss.item())
            train_batch_accuracy.append(accuracy)

        model.train(False)
        with torch.no_grad():
            for val_batch_id, (data, labels) in enumerate(validation_loader):
                data = data.to(device)
                labels = labels.to(device)
                out = model(data)
                # out = out[-1,:,:].squeeze()
                loss = loss_fn(out, labels)
                pred = out.detach().cpu().numpy() > output_threshold
                accuracy = np.sum(pred == labels.cpu().numpy(
                    ))/(labels.shape[0]*labels.shape[1]*labels.shape[2])
                validation_batch_loss.append(loss.item())
                validation_batch_accuracy.append(accuracy)

        scheduler.step(loss)

        training_losses.append(sum(train_batch_loss)/(train_batch_id + 1))
        validation_losses.append(sum(validation_batch_loss)/(val_batch_id + 1))
        training_accuracy.append(
            sum(train_batch_accuracy)/(train_batch_id + 1))
        validation_accuracy.append(
            sum(validation_batch_accuracy)/(val_batch_id + 1))

        # print out epoch metrics
        print('-'*15)

        print("Epoch: {}:".format(e+1))
        print("\t train loss: {:.2f}, validation loss: {:.2f}".format(
            training_losses[-1], validation_losses[-1]))
        print("\t train accuracy: {:.2f}, validation accuracy: {:.2f}".format(
            training_accuracy[-1], validation_accuracy[-1]))

        if best_validation_loss > validation_losses[-1]:
            best_validation_loss = validation_losses[-1]
            model_path = './Models/model_{}_{}.pt'.format(timestamp, e+1)
            torch.save(model.state_dict(), model_path)

    return training_losses, validation_losses, training_accuracy, validation_accuracy

# %%
def collate_fn(batch):
    tensors, targets = [], []
    for waveform, label in batch:
        tensors += [waveform.squeeze().t().float()]
        targets += [label]
    tensors = torch.stack(tensors)
    targets = torch.stack(targets)
    return tensors, targets

def create_dataloader(data, batch_size):
    dataloader = DataLoader(data, batch_size=batch_size, shuffle=True,
                                  drop_last=True, num_workers=0, pin_memory=True, collate_fn=collate_fn)
    return dataloader

# %%
def label_encoder(labels, windows, sample_rate):
    labels_dict = {label: i for i, label in enumerate(ALL_LABELS)}
    labels_array = torch.zeros(windows, len(ALL_LABELS))
    start = 0
    end = 15*sample_rate
    window_size = (end - start) / windows
    row_starts = labels['start'].to_numpy() * sample_rate
    row_ends = labels['end'].to_numpy() * sample_rate
    for i in range(windows):
        win_start = i*window_size + start
        win_end = win_start + window_size
        relevant_rows = (row_starts <= win_start) & (row_ends >= win_end)
        relevant_labels = labels['class'].to_numpy()[relevant_rows]
        label_indices = [labels_dict[label] for label in relevant_labels]
        labels_array[i, label_indices] = 1
    return labels_array

# %% [markdown]
# ##Train LSTM

# %%
if __name__ == "__main__":
    list_files = []
    data_folder = train_data_path
    for file in os.listdir(data_folder):
        if file.endswith(".wav"):
            list_files.append(os.path.join(
                data_folder, os.path.splitext(file)[0]))

    signal_transforms = []
    window_function = torch.hamming_window
    window_length = 256
    hop_length = 64
    n_bands = 256
    spectrogram = torchaudio.transforms.Spectrogram(
        # sample_rate=SAMPLE_RATE,
        n_fft=n_bands,
        win_length=window_length,
        hop_length=hop_length,
        window_fn=window_function
    )

    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_fft=n_bands,
        win_length=window_length,
        hop_length=hop_length,
        window_fn=window_function,
        n_mels=n_bands//2 +1,
        f_min=0,
        f_max=SAMPLE_RATE
    )

    n_mfccs = 60
    mfcc = torchaudio.transforms.MFCC(
        sample_rate=SAMPLE_RATE,
        n_mfcc=n_mfccs,
        log_mels=True,
        melkwargs={"n_fft": n_bands, 
                "win_length":window_length,
                "hop_length": hop_length, 
                "n_mels": n_bands//2 + 1,
                "window_fn": window_function, 
                "f_min": 0,
                "f_max": SAMPLE_RATE},
    )
    num_features = 0
    
    # signal_transforms.append(spectrogram)
    # num_features += (n_bands//2 + 1)
    
    # signal_transforms.append(mfcc)
    # num_features += n_mfccs

    signal_transforms.append(mel_spectrogram)
    num_features += (n_bands//2 + 1)
    
    seed = 0
    set_random_seeds(seed)
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    print(f"Using device {device}")
    train = LungDataSet(list_files, transformations=signal_transforms,
                        targets_transform=label_encoder)
    train_dataset, validation_dataset = random_split(train, [np.floor(len(
        list_files)*0.9).astype(int), len(list_files) - np.floor(len(list_files)*0.9).astype(int)])

    batch_size = 256

    train_loader = create_dataloader(train_dataset, batch_size)
    validation_loader = create_dataloader(validation_dataset, batch_size)

    num_windows = np.ceil(15*SAMPLE_RATE/hop_length)
    
    hidden_layers = 128
    model = Net_1(input_dimensions=num_features, n_hidden=hidden_layers, output_dimensions=len(
        ALL_LABELS), n_layers=1, drop_prob=0, bidirectional=True, device=device)

    learning_rate = 0.0001
    num_epochs = 50
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=10, factor=0.2)

    training_losses, validation_losses, training_accuracy, validation_accuracy = train_model(
        num_epochs, model, optimizer, scheduler, loss_fn, train_loader, validation_loader, device)

    plt.figure(figsize=(4, 6))
    plt.plot(training_losses, label="train_loss")
    plt.plot(validation_losses, label="validation_loss")
    plt.legend()
    plt.title("Loss")
    plt.show()
    plt.clf()

    plt.figure(figsize=(4, 6))
    plt.plot(training_accuracy, label="train_accuracy")
    plt.plot(validation_accuracy, label="validation_accuracy")
    plt.legend()
    plt.title("Accuracy")
    plt.show()
    plt.clf()

# %% [markdown]
# ##Training GRU

# %%
if __name__ == "__main__":
    list_files = []
    data_folder = train_data_path
    for file in os.listdir(data_folder):
        if file.endswith(".wav"):
            list_files.append(os.path.join(
                data_folder, os.path.splitext(file)[0]))

    signal_transforms = []
    window_function = torch.hamming_window
    window_length = 256
    hop_length = 64
    n_bands = 256
    spectrogram = torchaudio.transforms.Spectrogram(
        # sample_rate=SAMPLE_RATE,
        n_fft=n_bands,
        win_length=window_length,
        hop_length=hop_length,
        window_fn=window_function
    )

    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_fft=n_bands,
        win_length=window_length,
        hop_length=hop_length,
        window_fn=window_function,
        n_mels=n_bands//2 +1,
        f_min=0,
        f_max=SAMPLE_RATE
    )

    n_mfccs = 60
    mfcc = torchaudio.transforms.MFCC(
        sample_rate=SAMPLE_RATE,
        n_mfcc=n_mfccs,
        log_mels=True,
        melkwargs={"n_fft": n_bands, 
                "win_length":window_length,
                "hop_length": hop_length, 
                "n_mels": n_bands//2 + 1,
                "window_fn": window_function, 
                "f_min": 0,
                "f_max": SAMPLE_RATE},
    )
    num_features = 0
    
    # signal_transforms.append(spectrogram)
    # num_features += (n_bands//2 + 1)
    
    # signal_transforms.append(mfcc)
    # num_features += n_mfccs

    signal_transforms.append(mel_spectrogram)
    num_features += (n_bands//2 + 1)
    
    seed = 0
    set_random_seeds(seed)
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    print(f"Using device {device}")
    train = LungDataSet(list_files, transformations=signal_transforms,
                        targets_transform=label_encoder)
    train_dataset, validation_dataset = random_split(train, [np.floor(len(
        list_files)*0.9).astype(int), len(list_files) - np.floor(len(list_files)*0.9).astype(int)])

    batch_size = 256

    train_loader = create_dataloader(train_dataset, batch_size)
    validation_loader = create_dataloader(validation_dataset, batch_size)

    num_windows = np.ceil(15*SAMPLE_RATE/hop_length)
    
    hidden_layers = 128
    model = GRUNet(input_dimensions=num_features, n_hidden=hidden_layers, output_dimensions=len(
        ALL_LABELS), n_layers=1, drop_prob=0, bidirectional=True, device=device)

    learning_rate = 0.0001
    num_epochs = 50
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=10, factor=0.2)

    training_losses, validation_losses, training_accuracy, validation_accuracy = train_model(
        num_epochs, model, optimizer, scheduler, loss_fn, train_loader, validation_loader, device)

    plt.figure(figsize=(4, 6))
    plt.plot(training_losses, label="train_loss")
    plt.plot(validation_losses, label="validation_loss")
    plt.legend()
    plt.title("Loss")
    plt.show()
    plt.clf()

    plt.figure(figsize=(4, 6))
    plt.plot(training_accuracy, label="train_accuracy")
    plt.plot(validation_accuracy, label="validation_accuracy")
    plt.legend()
    plt.title("Accuracy")
    plt.show()
    plt.clf()
# Out:
# /usr/local/lib/python3.9/dist-packages/torchaudio/functional/functional.py:576: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (129) may be set too high. Or, the value for `n_freqs` (129) may be set too low.
#   warnings.warn(
# Random seed 0 has been set.
# Using device cuda
# ---------------
# Epoch: 1:
# 	 train loss: 0.67, validation loss: 0.65
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 2:
# 	 train loss: 0.63, validation loss: 0.60
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 3:
# 	 train loss: 0.57, validation loss: 0.53
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 4:
# 	 train loss: 0.45, validation loss: 0.32
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 5:
# 	 train loss: 0.27, validation loss: 0.26
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 6:
# 	 train loss: 0.26, validation loss: 0.26
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 7:
# 	 train loss: 0.25, validation loss: 0.25
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 8:
# 	 train loss: 0.25, validation loss: 0.25
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 9:
# 	 train loss: 0.25, validation loss: 0.25
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 10:
# 	 train loss: 0.25, validation loss: 0.25
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 11:
# 	 train loss: 0.24, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 12:
# 	 train loss: 0.24, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 13:
# 	 train loss: 0.24, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 14:
# 	 train loss: 0.24, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 15:
# 	 train loss: 0.24, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 16:
# 	 train loss: 0.23, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 17:
# 	 train loss: 0.23, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 18:
# 	 train loss: 0.23, validation loss: 0.24
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 19:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 20:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 21:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 22:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 23:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 24:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 25:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 26:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 27:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 28:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.91, validation accuracy: 0.91
# ---------------
# Epoch: 29:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 30:
# 	 train loss: 0.23, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 31:
# 	 train loss: 0.22, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 32:
# 	 train loss: 0.22, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 33:
# 	 train loss: 0.22, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 34:
# 	 train loss: 0.22, validation loss: 0.23
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 35:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 36:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 37:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.91
# ---------------
# Epoch: 38:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 39:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 40:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 41:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 42:
# 	 train loss: 0.22, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 43:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 44:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 45:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 46:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 47:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
# ---------------
# Epoch: 48:
# 	 train loss: 0.21, validation loss: 0.22
# 	 train accuracy: 0.92, validation accuracy: 0.92
